# %% [markdown]
# # Report
#
# ---
#
#
# ### 1. Implementations
# The report is to describe the implementations of Deep Deterministic Policy Gradient (ddpg) to the continous project.

# %% [markdown]
# ### 2. Algorithm
# #### Algorithm
# The algorithm used ddpg for continous control.
#
# #### Hyperparameters
# The action, states and reward information of all the simulation environments were feed to one agent to learn.
# The learning process start once after 20 time steps.
#
# #### model architectures
#
# Two hidden layer is used in the application and have 400 and 300 nodes respectively

# %% [markdown]
# ### 3. Plot of reward

# %%
from IPython.display import Image
from IPython.core.display import HTML
#PATH = "/Users/reblochonMasque/Documents/Drawings/"
Image(filename = "reward.png", width=400, height=400)

# %% [markdown]
# ### 4. Future ideas
# The future work is to combine ddpg as energy fuction and when the system is close to stable and use classical control to regulate them.
